# %%
import pandas as pd

# %%
inventory_parts = pd.read_csv('data/inventory_parts.csv')
parts = pd.read_csv('data/parts.csv')
colors = pd.read_csv('data/colors.csv')

# %%
lego_parts = pd.merge(inventory_parts, parts,'left', on='part_num' )

# %%
lego_parts = pd.merge(lego_parts, colors,'left', left_on='color_id', right_on='id')
lego_parts.head()
# Out:
#    inventory_id        part_num  color_id  quantity is_spare  \
# 0             1        48379c04        72         1        f
# 1             1           48391         0         1        f
# 2             1           48395         7         1        f
# 3             1        48864c01        25         1        f
# 4             1  stickerupn0077      9999         1        f
#
#                                              img_url  \
# 0  https://cdn.rebrickable.com/media/parts/photos...
# 1  https://cdn.rebrickable.com/media/parts/photos...
# 2  https://cdn.rebrickable.com/media/parts/photos...
# 3                                                NaN
# 4                                                NaN
#
#                                               name_x  part_cat_id  \
# 0       Large Figure Torso and Legs, with Black Feet           41
# 1    Sports Promo Paddle from McDonald's Sports Sets           27
# 2   Sports Snowboard from McDonald's Promotional Set           27
# 3  Sports Promo Figure Head Torso Assembly McDona...           13
# 4                       Sticker Sheet for Set 7922-1           58
#
#   part_material  id_x                name_y   rgb_x is_trans_x  id_y  \
# 0       Plastic    72      Dark Bluish Gray  6C6E68          f    72
# 1       Plastic     0                 Black  05131D          f     0
# 2       Plastic     7            Light Gray  9BA19D          f     7
# 3       Plastic    25                Orange  FE8A18          f    25
# 4       Plastic  9999  [No Color/Any Color]  05131D          f  9999
#
#                    name   rgb_y is_trans_y
# 0      Dark Bluish Gray  6C6E68          f
# 1                 Black  05131D          f
# 2            Light Gray  9BA19D          f
# 3                Orange  FE8A18          f
# 4  [No Color/Any Color]  05131D          f

# %%
lego_parts = lego_parts[["part_num", "name_x", "name_y", "img_url"]]
print(len(lego_parts))
print(len(lego_parts))
lego_parts.rename(columns={"part_num": "part_id", "name_x": 'part_name', 'name_y':'color_name', 'img_url': 'part_png'}, inplace=True)
# Out:
# 1298187
# 1298187

# %%
lego_parts.drop_duplicates(subset=['part_id', 'color_name', 'part_png'])
print(len(lego_parts))
lego_parts.head()
lego_parts.to_csv('data/lego_parts.csv')
# Out:
# 1298187

# %%
print(len(pd.read_csv('data/lego_parts.csv')))
# Out:
# 77949

# %%
lego_sets = pd.read_csv('data/sets.csv')
lego_sets.head()
# Out:
#         set_num                         name  year  theme_id  num_parts  \
# 0  0003977811-1  Ninjago: Book of Adventures  2022       761          1
# 1         001-1                        Gears  1965       756         43
# 2        0011-2            Town Mini-Figures  1979        67         12
# 3        0011-3   Castle 2 for 1 Bonus Offer  1987       199          0
# 4        0012-1           Space Mini-Figures  1979       143         12
#
#                                              img_url
# 0  https://cdn.rebrickable.com/media/sets/0003977...
# 1   https://cdn.rebrickable.com/media/sets/001-1.jpg
# 2  https://cdn.rebrickable.com/media/sets/0011-2.jpg
# 3  https://cdn.rebrickable.com/media/sets/0011-3.jpg
# 4  https://cdn.rebrickable.com/media/sets/0012-1.jpg

# %%
lego_sets.to_csv('data/lego_builds.csv')

# %%
inventory_parts = pd.read_csv('data/inventory_parts.csv')
colors = pd.read_csv('data/colors.csv')
inventories = pd.read_csv('data/inventories.csv')

# %%
inventory_parts = pd.merge(inventory_parts, colors,'left', left_on='color_id', right_on='id')
build_details = pd.merge(inventory_parts, inventories, 'left', left_on='inventory_id', right_on='id')
build_details.head( )
# Out:
#    inventory_id        part_num  color_id  quantity is_spare  \
# 0             1        48379c04        72         1        f
# 1             1           48391         0         1        f
# 2             1           48395         7         1        f
# 3             1        48864c01        25         1        f
# 4             1  stickerupn0077      9999         1        f
#
#                                              img_url  id_x  \
# 0  https://cdn.rebrickable.com/media/parts/photos...    72
# 1  https://cdn.rebrickable.com/media/parts/photos...     0
# 2  https://cdn.rebrickable.com/media/parts/photos...     7
# 3                                                NaN    25
# 4                                                NaN  9999
#
#                  name_x   rgb_x is_trans_x  id_y                name_y  \
# 0      Dark Bluish Gray  6C6E68          f    72      Dark Bluish Gray
# 1                 Black  05131D          f     0                 Black
# 2            Light Gray  9BA19D          f     7            Light Gray
# 3                Orange  FE8A18          f    25                Orange
# 4  [No Color/Any Color]  05131D          f  9999  [No Color/Any Color]
#
#     rgb_y is_trans_y  id  version set_num
# 0  6C6E68          f   1        1  7922-1
# 1  05131D          f   1        1  7922-1
# 2  9BA19D          f   1        1  7922-1
# 3  FE8A18          f   1        1  7922-1
# 4  05131D          f   1        1  7922-1

# %%
build_details.to_csv('data/build_details.csv')

# %%
df = pd.read_csv('data/has_theme.csv')

for index, row in df.iterrows():
    print(f'INSERT INTO BUILD_HAS_THEME VALUES("{row['build_id']}", {row['theme_id']});')
# Out:
# INSERT INTO BUILD_HAS_THEME VALUES("0003977811-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("001-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("0011-2", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("0011-3", 199   );
# INSERT INTO BUILD_HAS_THEME VALUES("0012-1", 143   );
# INSERT INTO BUILD_HAS_THEME VALUES("0013-1", 143   );
# INSERT INTO BUILD_HAS_THEME VALUES("0014-1", 143   );
# INSERT INTO BUILD_HAS_THEME VALUES("0015-1", 143   );
# INSERT INTO BUILD_HAS_THEME VALUES("0016-1", 189   );
# INSERT INTO BUILD_HAS_THEME VALUES("002-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("002253963-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("003-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("004-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("005-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("005-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("00-6", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("010-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("010-2", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("010-3", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("010423-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Jan", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("011-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("2-Jan", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Feb", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("021-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("2-Feb", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("022-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("022-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("0241187567-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("0241357594-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("028-1", 652   );
# INSERT INTO BUILD_HAS_THEME VALUES("030-2", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("03093-1", 674   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Mar", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("032-1", 652   );
# INSERT INTO BUILD_HAS_THEME VALUES("033-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("033-2", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Apr", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("041-1", 369   );
# INSERT INTO BUILD_HAS_THEME VALUES("041-2", 652   );
# INSERT INTO BUILD_HAS_THEME VALUES("042-1", 369   );
# INSERT INTO BUILD_HAS_THEME VALUES("044-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("044-2", 369   );
# INSERT INTO BUILD_HAS_THEME VALUES("045-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("045-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("047-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("049-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("050-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-May", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("051-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("052-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("053-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("054-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("055-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("055-2", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("057-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("058-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("060-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("060-3", 369   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Jun", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("061-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("062-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("063-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("063-2", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("065-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("066-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("066-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Jul", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("071-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("074-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("075-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("0751359483-1", 758   );
# INSERT INTO BUILD_HAS_THEME VALUES("0756668530-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("0756672805-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("0756682762-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("0756692571-1", 758   );
# INSERT INTO BUILD_HAS_THEME VALUES("077-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("078-1", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("080-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("080-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("080-3", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Aug", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("082-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("085-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("086-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("0878119001641-1", 740   );
# INSERT INTO BUILD_HAS_THEME VALUES("088-1", 465   );
# INSERT INTO BUILD_HAS_THEME VALUES("0906946506-1", 759   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Sep", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("10000-1", 199   );
# INSERT INTO BUILD_HAS_THEME VALUES("10000549412-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10001-1", 233   );
# INSERT INTO BUILD_HAS_THEME VALUES("10002-1", 233   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000229927-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("10003-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000368666-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("10004-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000430096-8", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("10005-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000565140-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000565190-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000565740-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000565742-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000565765-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000565897-5", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000577871-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000591519-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000591524-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000598000-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000600263-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("10006-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000629598-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000643461-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000648795-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000692713-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000704831-2", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000704832-13", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000709804-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000709806-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000709807-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("10007-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000724950-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000724951-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000739974-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000739975-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000739976-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("1000746530-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("10008-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10009-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("100-1", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("10010-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10011-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10012-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10013-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10014-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10015-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10016-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10017-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10018-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10019-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("100-2", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("10020-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10020-2", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10021-1", 404   );
# INSERT INTO BUILD_HAS_THEME VALUES("10022-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10023-1", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("10024-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10025-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10026-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10027-1", 105   );
# INSERT INTO BUILD_HAS_THEME VALUES("10029-1", 387   );
# INSERT INTO BUILD_HAS_THEME VALUES("100291707-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100291708-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10030-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("100301705-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100301837-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100302101-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100302203-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100302304-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100311708-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100311837-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100321710-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100341707-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100341726-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100341829-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100342004-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100342008-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100342101-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100342108-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100342208-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100351702-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100351707-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100351708-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100351710-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10036-1", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("10037-1", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("10039-1", 187   );
# INSERT INTO BUILD_HAS_THEME VALUES("10040-1", 148   );
# INSERT INTO BUILD_HAS_THEME VALUES("10041-1", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("10042-1", 206   );
# INSERT INTO BUILD_HAS_THEME VALUES("10043-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10044-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10045-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("100451835-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100451910-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100451914-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100452005-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10046-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10047-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10048-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10049-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10050-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("100501829-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100501908-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100502101-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100502108-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100502206-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100502207-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100502208-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("10051-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10052-1", 634   );
# INSERT INTO BUILD_HAS_THEME VALUES("100522009-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100522101-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100522108-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("100522110-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("10053-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10054-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10055-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10056-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10057-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10058-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10059-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10060-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("100603-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10061-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10062-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10063-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10064-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10065-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10066-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10067-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10068-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10069-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10070-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10071-1", 229   );
# INSERT INTO BUILD_HAS_THEME VALUES("10072-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("100722101-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100722106-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100722108-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100722110-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10073-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10074-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10075-1", 706   );
# INSERT INTO BUILD_HAS_THEME VALUES("10076-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10077-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10078-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10079-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10080-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10081-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("100812101-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("100812102-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10082-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("10083-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("100871-1", 503   );
# INSERT INTO BUILD_HAS_THEME VALUES("10090-1", 231   );
# INSERT INTO BUILD_HAS_THEME VALUES("100STORES-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("1-Oct", 465   );
# INSERT INTO BUILD_HAS_THEME VALUES("1010205-1", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("1010206-1", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("1010207-1", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("1010208-1", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("101032211-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("101032303-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("1010405-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("1010408-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("101042213-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("101042303-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("101042313-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("101052211-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10106-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("101-1", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("1011-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10111-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10112-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10113-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10114-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10115-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10116-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("10117-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("10118-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("101-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("1012-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10121-1", 459   );
# INSERT INTO BUILD_HAS_THEME VALUES("10123-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10124-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10127-1", 461   );
# INSERT INTO BUILD_HAS_THEME VALUES("10128-1", 105   );
# INSERT INTO BUILD_HAS_THEME VALUES("10128-2", 105   );
# INSERT INTO BUILD_HAS_THEME VALUES("10129-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("101-3", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("1013-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10131-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10132-1", 246   );
# INSERT INTO BUILD_HAS_THEME VALUES("10133-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10134-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10135-1", 500   );
# INSERT INTO BUILD_HAS_THEME VALUES("1014-1", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("1014-2", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10143-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10144-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10145-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10146-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10147-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10148-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10149-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10150-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1015-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10151-1", 278   );
# INSERT INTO BUILD_HAS_THEME VALUES("10152-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10152-2", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10152-3", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10153-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("10155-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10156-1", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("10157-1", 105   );
# INSERT INTO BUILD_HAS_THEME VALUES("10158-1", 105   );
# INSERT INTO BUILD_HAS_THEME VALUES("10159-1", 53   );
# INSERT INTO BUILD_HAS_THEME VALUES("10159-2", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("10160-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("1016-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10161-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10162-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10163-1", 254   );
# INSERT INTO BUILD_HAS_THEME VALUES("10165-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10166-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10167-1", 301   );
# INSERT INTO BUILD_HAS_THEME VALUES("10168-1", 229   );
# INSERT INTO BUILD_HAS_THEME VALUES("10169-1", 229   );
# INSERT INTO BUILD_HAS_THEME VALUES("10170-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("1017-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10173-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10174-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10175-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10176-1", 198   );
# INSERT INTO BUILD_HAS_THEME VALUES("10177-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10178-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10179-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("1018-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10181-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10182-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10183-1", 397   );
# INSERT INTO BUILD_HAS_THEME VALUES("10184-1", 104   );
# INSERT INTO BUILD_HAS_THEME VALUES("10185-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10186-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10187-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10188-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10189-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10190-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("1019-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10191-1", 397   );
# INSERT INTO BUILD_HAS_THEME VALUES("10192-1", 397   );
# INSERT INTO BUILD_HAS_THEME VALUES("10193-1", 193   );
# INSERT INTO BUILD_HAS_THEME VALUES("10194-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10195-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10196-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10197-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10198-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10199-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("2-Oct", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("10200-1", 397   );
# INSERT INTO BUILD_HAS_THEME VALUES("1020-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10201-1", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("10202-1", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("10202-2", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("10203-1", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("10204-1", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("10205-1", 236   );
# INSERT INTO BUILD_HAS_THEME VALUES("102-1", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("10210-1", 153   );
# INSERT INTO BUILD_HAS_THEME VALUES("1021-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10211-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10212-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10213-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10213sup-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("10214-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10215-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10216-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10217-1", 246   );
# INSERT INTO BUILD_HAS_THEME VALUES("10218-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10219-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("102-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("10220-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("1022-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10221-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10222-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10223-1", 196   );
# INSERT INTO BUILD_HAS_THEME VALUES("10224-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10225-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10226-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10227-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10228-1", 558   );
# INSERT INTO BUILD_HAS_THEME VALUES("10229-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("102-3", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("10230-1", 156   );
# INSERT INTO BUILD_HAS_THEME VALUES("1023-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10231-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10232-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10233-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10234-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10235-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("10236-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("10237-1", 566   );
# INSERT INTO BUILD_HAS_THEME VALUES("10240-1", 171   );
# INSERT INTO BUILD_HAS_THEME VALUES("1024-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10241-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10242-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10242-2", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10243-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10244-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10245-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("1024601-1", 297   );
# INSERT INTO BUILD_HAS_THEME VALUES("10246-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10247-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10248-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10249-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("10250-1", 206   );
# INSERT INTO BUILD_HAS_THEME VALUES("1025-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10251-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10252-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10253-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10254-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("10255-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10256-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10257-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10258-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10259-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("10260-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("1026-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10261-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10262-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10263-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("10264-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10265-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10266-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10267-1", 228   );
# INSERT INTO BUILD_HAS_THEME VALUES("10268-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10269-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10270-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("1027-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10271-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10272-1", 673   );
# INSERT INTO BUILD_HAS_THEME VALUES("10273-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10274-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10275-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10276-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10277-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10278-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10279-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10280-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1028-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10281-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10282-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10282-2", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10283-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10284-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10285-1", 259   );
# INSERT INTO BUILD_HAS_THEME VALUES("10287-1", 259   );
# INSERT INTO BUILD_HAS_THEME VALUES("10289-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10290-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1029-1", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("10291-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10292-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10293-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10294-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10295-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10297-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10298-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10299-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("102A-1", 416   );
# INSERT INTO BUILD_HAS_THEME VALUES("102A-2", 416   );
# INSERT INTO BUILD_HAS_THEME VALUES("10300-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1030-1", 1   );
# INSERT INTO BUILD_HAS_THEME VALUES("10302-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10303-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10304-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10305-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10306-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10307-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10308-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10309-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("103-1", 473   );
# INSERT INTO BUILD_HAS_THEME VALUES("1031-1", 529   );
# INSERT INTO BUILD_HAS_THEME VALUES("10311-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10312-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10313-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10314-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10315-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10316-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10317-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10318-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("103-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("10320-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1032-1", 529   );
# INSERT INTO BUILD_HAS_THEME VALUES("10321-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10323-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10325-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10326-1", 155   );
# INSERT INTO BUILD_HAS_THEME VALUES("10327-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10328-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10329-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10330-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("103303-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("1033-1", 529   );
# INSERT INTO BUILD_HAS_THEME VALUES("10331-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10332-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10333-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10334-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10337-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10338-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10339-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("10340-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1034-1", 529   );
# INSERT INTO BUILD_HAS_THEME VALUES("10341-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("103558-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("103660-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10368-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10369-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10370-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1038-1", 1   );
# INSERT INTO BUILD_HAS_THEME VALUES("1039-1", 1   );
# INSERT INTO BUILD_HAS_THEME VALUES("10391-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("1040-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10401-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("1040-2", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10402-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("1040-3", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10403-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10404-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10405-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("104-1", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("1041-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10411-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("1041-2", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10412-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10413-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10414-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10415-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10416-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10417-1", 506   );
# INSERT INTO BUILD_HAS_THEME VALUES("10418-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("10419-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("104-2", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("10420-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("1042-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10421-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("1042-2", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10422-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10423-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10424-1", 630   );
# INSERT INTO BUILD_HAS_THEME VALUES("1043-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10431-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10432-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10433-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10434-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10435-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("10437728-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("10438-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10439-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("1044-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("1045-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("1045-2", 511   );
# INSERT INTO BUILD_HAS_THEME VALUES("1046-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("104655-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("1047-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("1048-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("1049-1", 507   );
# INSERT INTO BUILD_HAS_THEME VALUES("10497-1", 721   );
# INSERT INTO BUILD_HAS_THEME VALUES("10500-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("1050-1", 534   );
# INSERT INTO BUILD_HAS_THEME VALUES("10501-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10502-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10503-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10504-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10505-1", 652   );
# INSERT INTO BUILD_HAS_THEME VALUES("10506-1", 634   );
# INSERT INTO BUILD_HAS_THEME VALUES("10507-1", 634   );
# INSERT INTO BUILD_HAS_THEME VALUES("10508-1", 634   );
# INSERT INTO BUILD_HAS_THEME VALUES("10509-1", 627   );
# INSERT INTO BUILD_HAS_THEME VALUES("105-1", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("10510-1", 627   );
# INSERT INTO BUILD_HAS_THEME VALUES("10511-1", 627   );
# INSERT INTO BUILD_HAS_THEME VALUES("10512-1", 638   );
# INSERT INTO BUILD_HAS_THEME VALUES("10513-1", 638   );
# INSERT INTO BUILD_HAS_THEME VALUES("10514-1", 638   );
# INSERT INTO BUILD_HAS_THEME VALUES("10515-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("10516-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("10517-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10518-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10519-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("105-2", 465   );
# INSERT INTO BUILD_HAS_THEME VALUES("10520-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10521-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10522-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10524-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10525-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10526-1", 638   );
# INSERT INTO BUILD_HAS_THEME VALUES("10527-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10528-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10529-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("105-3", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("1053-1", 533   );
# INSERT INTO BUILD_HAS_THEME VALUES("10531-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10532-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("105334-1", 735   );
# INSERT INTO BUILD_HAS_THEME VALUES("10538-1", 627   );
# INSERT INTO BUILD_HAS_THEME VALUES("10539-1", 638   );
# INSERT INTO BUILD_HAS_THEME VALUES("1054-1", 471   );
# INSERT INTO BUILD_HAS_THEME VALUES("10542-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("10543-1", 653   );
# INSERT INTO BUILD_HAS_THEME VALUES("10544-1", 653   );
# INSERT INTO BUILD_HAS_THEME VALUES("10545-1", 653   );
# INSERT INTO BUILD_HAS_THEME VALUES("10546-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10550-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("1055-1", 534   );
# INSERT INTO BUILD_HAS_THEME VALUES("10552-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10553-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10554-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10555-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10556-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10557-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10558-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10559-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10560-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("1056-1", 534   );
# INSERT INTO BUILD_HAS_THEME VALUES("10561-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10565-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10566-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10567-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10568-1", 647   );
# INSERT INTO BUILD_HAS_THEME VALUES("10569-1", 647   );
# INSERT INTO BUILD_HAS_THEME VALUES("10570-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10571-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10572-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10573-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10574-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10575-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10576-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10577-1", 647   );
# INSERT INTO BUILD_HAS_THEME VALUES("10579-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10580-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10581-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10582-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10583-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10584-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10585-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10586-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10587-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10589-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10590-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10591-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10592-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10593-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10594-1", 639   );
# INSERT INTO BUILD_HAS_THEME VALUES("10595-1", 639   );
# INSERT INTO BUILD_HAS_THEME VALUES("10596-1", 640   );
# INSERT INTO BUILD_HAS_THEME VALUES("10597-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10599-1", 653   );
# INSERT INTO BUILD_HAS_THEME VALUES("10600-1", 506   );
# INSERT INTO BUILD_HAS_THEME VALUES("1060-1", 533   );
# INSERT INTO BUILD_HAS_THEME VALUES("10601-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10602-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10603-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10604-1", 638   );
# INSERT INTO BUILD_HAS_THEME VALUES("10605-1", 648   );
# INSERT INTO BUILD_HAS_THEME VALUES("10606-1", 648   );
# INSERT INTO BUILD_HAS_THEME VALUES("10607-1", 630   );
# INSERT INTO BUILD_HAS_THEME VALUES("10608-1", 630   );
# INSERT INTO BUILD_HAS_THEME VALUES("106-1", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("1061-1", 20   );
# INSERT INTO BUILD_HAS_THEME VALUES("10615-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10616-1", 652   );
# INSERT INTO BUILD_HAS_THEME VALUES("10617-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10618-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("1062-1", 533   );
# INSERT INTO BUILD_HAS_THEME VALUES("10622-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10623-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("1063-1", 533   );
# INSERT INTO BUILD_HAS_THEME VALUES("1064-1", 533   );
# INSERT INTO BUILD_HAS_THEME VALUES("1065-1", 534   );
# INSERT INTO BUILD_HAS_THEME VALUES("10654-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10655-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10656-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10657-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10659-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10659-2", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10660-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("1066-1", 533   );
# INSERT INTO BUILD_HAS_THEME VALUES("10661-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10662-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10663-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10664-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10665-1", 596   );
# INSERT INTO BUILD_HAS_THEME VALUES("10666-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10667-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10668-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10669-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("1067-1", 507   );
# INSERT INTO BUILD_HAS_THEME VALUES("10671-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10672-1", 592   );
# INSERT INTO BUILD_HAS_THEME VALUES("10673-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10674-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10675-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10676-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10677-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10679-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10680-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("1068-1", 87   );
# INSERT INTO BUILD_HAS_THEME VALUES("10681-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10682-1", 35   );
# INSERT INTO BUILD_HAS_THEME VALUES("10683-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10684-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10685-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10686-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10687-1", 596   );
# INSERT INTO BUILD_HAS_THEME VALUES("1069-1", 92   );
# INSERT INTO BUILD_HAS_THEME VALUES("10692-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10693-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10694-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10695-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10696-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10697-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10698-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10699-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10700-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("1070-1", 87   );
# INSERT INTO BUILD_HAS_THEME VALUES("10701-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10702-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10703-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10704-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10705-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10706-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10707-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10708-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10709-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("107-1", 473   );
# INSERT INTO BUILD_HAS_THEME VALUES("1071-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10712-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10713-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10714-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10715-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("10717-1", 621   );
# INSERT INTO BUILD_HAS_THEME VALUES("107-2", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("10720-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10721-1", 596   );
# INSERT INTO BUILD_HAS_THEME VALUES("10722-1", 597   );
# INSERT INTO BUILD_HAS_THEME VALUES("10723-1", 593   );
# INSERT INTO BUILD_HAS_THEME VALUES("10724-1", 592   );
# INSERT INTO BUILD_HAS_THEME VALUES("10725-1", 597   );
# INSERT INTO BUILD_HAS_THEME VALUES("10726-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10727-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10728-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10729-1", 593   );
# INSERT INTO BUILD_HAS_THEME VALUES("107-3", 756   );
# INSERT INTO BUILD_HAS_THEME VALUES("10730-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10731-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10732-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10733-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10734-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10735-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10736-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10737-1", 592   );
# INSERT INTO BUILD_HAS_THEME VALUES("10738-1", 593   );
# INSERT INTO BUILD_HAS_THEME VALUES("10739-1", 597   );
# INSERT INTO BUILD_HAS_THEME VALUES("10740-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10742-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10743-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10744-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10745-1", 615   );
# INSERT INTO BUILD_HAS_THEME VALUES("10746-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10747-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10748-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10749-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10750-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("1075-1", 511   );
# INSERT INTO BUILD_HAS_THEME VALUES("10751-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10753-1", 592   );
# INSERT INTO BUILD_HAS_THEME VALUES("10754-1", 596   );
# INSERT INTO BUILD_HAS_THEME VALUES("107542-1", 735   );
# INSERT INTO BUILD_HAS_THEME VALUES("107544-1", 503   );
# INSERT INTO BUILD_HAS_THEME VALUES("10755-1", 597   );
# INSERT INTO BUILD_HAS_THEME VALUES("10756-1", 620   );
# INSERT INTO BUILD_HAS_THEME VALUES("10757-1", 620   );
# INSERT INTO BUILD_HAS_THEME VALUES("10758-1", 620   );
# INSERT INTO BUILD_HAS_THEME VALUES("10759-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10760-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("1076-1", 207   );
# INSERT INTO BUILD_HAS_THEME VALUES("10761-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10762-1", 593   );
# INSERT INTO BUILD_HAS_THEME VALUES("10763-1", 595   );
# INSERT INTO BUILD_HAS_THEME VALUES("10764-1", 591   );
# INSERT INTO BUILD_HAS_THEME VALUES("10765-1", 593   );
# INSERT INTO BUILD_HAS_THEME VALUES("10766-1", 275   );
# INSERT INTO BUILD_HAS_THEME VALUES("10767-1", 275   );
# INSERT INTO BUILD_HAS_THEME VALUES("10768-1", 275   );
# INSERT INTO BUILD_HAS_THEME VALUES("10769-1", 275   );
# INSERT INTO BUILD_HAS_THEME VALUES("10770-1", 275   );
# INSERT INTO BUILD_HAS_THEME VALUES("1077-1", 528   );
# INSERT INTO BUILD_HAS_THEME VALUES("10771-1", 275   );
# INSERT INTO BUILD_HAS_THEME VALUES("10772-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10773-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10774-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10775-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10776-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10777-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10778-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("10780-1", 388   );
# INSERT INTO BUILD_HAS_THEME VALUES("1078-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10781-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10782-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10783-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10784-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10785-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10786-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10787-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10788-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10789-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10790-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("1079-1", 516   );
# INSERT INTO BUILD_HAS_THEME VALUES("10791-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10792-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10793-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10794-1", 755   );
# INSERT INTO BUILD_HAS_THEME VALUES("10795-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10796-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10797-1", 748   );
# INSERT INTO BUILD_HAS_THEME VALUES("10801-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10802-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10803-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10804-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10805-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10806-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10807-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10808-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10809-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("108-1", 235   );
# INSERT INTO BUILD_HAS_THEME VALUES("10810-1", 634   );
# INSERT INTO BUILD_HAS_THEME VALUES("10811-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10812-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10813-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10814-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10815-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10816-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10817-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10818-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10819-1", 632   );
# INSERT INTO BUILD_HAS_THEME VALUES("10820-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10822-1", 639   );
# INSERT INTO BUILD_HAS_THEME VALUES("10823-1", 653   );
# INSERT INTO BUILD_HAS_THEME VALUES("10824-1", 629   );
# INSERT INTO BUILD_HAS_THEME VALUES("10825-1", 629   );
# INSERT INTO BUILD_HAS_THEME VALUES("10826-1", 629   );
# INSERT INTO BUILD_HAS_THEME VALUES("10827-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10828-1", 648   );
# INSERT INTO BUILD_HAS_THEME VALUES("10829-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10830-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("1083-1", 534   );
# INSERT INTO BUILD_HAS_THEME VALUES("10831-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10832-1", 636   );
# INSERT INTO BUILD_HAS_THEME VALUES("10833-1", 636   );
# INSERT INTO BUILD_HAS_THEME VALUES("10834-1", 636   );
# INSERT INTO BUILD_HAS_THEME VALUES("10835-1", 636   );
# INSERT INTO BUILD_HAS_THEME VALUES("10836-1", 636   );
# INSERT INTO BUILD_HAS_THEME VALUES("10837-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10838-1", 636   );
# INSERT INTO BUILD_HAS_THEME VALUES("10839-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10840-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10841-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10842-1", 653   );
# INSERT INTO BUILD_HAS_THEME VALUES("10843-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10844-1", 641   );
# INSERT INTO BUILD_HAS_THEME VALUES("10845-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10846-1", 506   );
# INSERT INTO BUILD_HAS_THEME VALUES("10847-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10848-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10849-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10850-1", 504   );
# INSERT INTO BUILD_HAS_THEME VALUES("10851-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10852-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("10853-1", 505   );
# ...
# INSERT INTO BUILD_HAS_THEME VALUES("QXI7343-1", 738   );
# INSERT INTO BUILD_HAS_THEME VALUES("QXI7506-1", 738   );
# INSERT INTO BUILD_HAS_THEME VALUES("QXI7555-1", 738   );
# INSERT INTO BUILD_HAS_THEME VALUES("QXI7562-1", 738   );
# INSERT INTO BUILD_HAS_THEME VALUES("QXI7576-1", 738   );
# INSERT INTO BUILD_HAS_THEME VALUES("R2D2-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("R2D2-2", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("RABBIT-1", 410   );
# INSERT INTO BUILD_HAS_THEME VALUES("RACERS-1", 118   );
# INSERT INTO BUILD_HAS_THEME VALUES("RACERS-2", 118   );
# INSERT INTO BUILD_HAS_THEME VALUES("RALEIGH-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("RAMBOLL-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("RANGOLI-1", 206   );
# INSERT INTO BUILD_HAS_THEME VALUES("RAT-1", 206   );
# INSERT INTO BUILD_HAS_THEME VALUES("RBS6003-1", 759   );
# INSERT INTO BUILD_HAS_THEME VALUES("REDSOX2016-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("REDSOX2019-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("REDTEMPLE-1", 435   );
# INSERT INTO BUILD_HAS_THEME VALUES("RHINO-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROBORIDER-1", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROBORIDER-2", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROCKBAND-1", 52   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROOSTER-1", 206   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROSE-1", 608   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROSE2-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("ROSEVILLE-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("RRMINIFIGS-1", 442   );
# INSERT INTO BUILD_HAS_THEME VALUES("RUG-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("S1-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("S2-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("S3-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("SAARBRUCKEN-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SAC6012-1", 760   );
# INSERT INTO BUILD_HAS_THEME VALUES("SAC6301-1", 760   );
# INSERT INTO BUILD_HAS_THEME VALUES("SAC6702-1", 760   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sacramento-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SANDIEGO-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SANFRANCISCO-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SANTACHIMNEY-1", 410   );
# INSERT INTO BUILD_HAS_THEME VALUES("SATCHEL-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2010-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2015-1", 702   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2015-2", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2015-3", 701   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2015-4", 696   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2015-5", 695   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2015-6", 324   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2016-1", 696   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2016-2", 695   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2018-1", 696   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2018-2", 695   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2018-3", 670   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2019-1", 706   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2019-2", 697   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2019-3", 680   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDCC2023-1", 503   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDIK-1", 603   );
# INSERT INTO BUILD_HAS_THEME VALUES("SDMYSTERYGANG-1", 603   );
# INSERT INTO BUILD_HAS_THEME VALUES("SHANGHAI-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SHANGHAICASTLE-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SHEEP-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sheffield-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("shell98small-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("SHTOWN99SMALL-1", 50   );
# INSERT INTO BUILD_HAS_THEME VALUES("SHUTTLE-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SLEEPER-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("SLEEPINGBAG-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("SLEIGHORNAMENT-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("SLIZER-1", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("SMMM-1", 706   );
# INSERT INTO BUILD_HAS_THEME VALUES("SoOuest-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp10-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp1-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp11-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp12-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp13-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp14-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp15-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp16-1", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp17-1", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp18-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp19-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp20-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp2-1", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp21-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp3-1", 453   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp5-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp6-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp7-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp8-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("Sp9-1", 456   );
# INSERT INTO BUILD_HAS_THEME VALUES("SpB-1", 443   );
# INSERT INTO BUILD_HAS_THEME VALUES("SPHINX-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("SQUIRREL-1", 505   );
# INSERT INTO BUILD_HAS_THEME VALUES("STAMP-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("STARTERHEART-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("STARWARSBOOK-1", 759   );
# INSERT INTO BUILD_HAS_THEME VALUES("STATIONERY-1", 739   );
# INSERT INTO BUILD_HAS_THEME VALUES("STATUEOFLIBERTY-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("STOCKHOLM-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("STORAGESOLUTION-1", 740   );
# INSERT INTO BUILD_HAS_THEME VALUES("STORMBREAKER-1", 702   );
# INSERT INTO BUILD_HAS_THEME VALUES("Stratford-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SUNRISE-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("SUPERMAN-1", 701   );
# INSERT INTO BUILD_HAS_THEME VALUES("SUPREMECOURT-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("sw117promo-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("SWCOMIC1-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("SWDVDBD-1", 730   );
# INSERT INTO BUILD_HAS_THEME VALUES("SWEEPSTAKE-1", 690   );
# INSERT INTO BUILD_HAS_THEME VALUES("SWMINIFIGS-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("SWMP-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("SWORD-1", 737   );
# INSERT INTO BUILD_HAS_THEME VALUES("SX0250-1", 735   );
# INSERT INTO BUILD_HAS_THEME VALUES("TEDDYBEAR-1", 232   );
# INSERT INTO BUILD_HAS_THEME VALUES("tf05-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("tf11-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-1", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-10", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-11", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-13", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-14", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-2", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-3", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-4", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-5", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-6", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-7", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-8", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("THROW-9", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("TIEFIGHTER-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TKTOUR-1", 458   );
# INSERT INTO BUILD_HAS_THEME VALUES("TLBM-1", 730   );
# INSERT INTO BUILD_HAS_THEME VALUES("TLMPS-1", 578   );
# INSERT INTO BUILD_HAS_THEME VALUES("TLNM-1", 616   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOMINIFIGS-1", 106   );
# INSERT INTO BUILD_HAS_THEME VALUES("Toronto-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("Toronto-2", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("Toronto-3", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("TORQUE-1", 269   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-2", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-3", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-4", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-5", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-6", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-7", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-8", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOTEBAG-9", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOUCAN-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOWEL-1", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOWEL-2", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOWEL-3", 733   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOYFAIR-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOYFAIR-2", 3   );
# INSERT INTO BUILD_HAS_THEME VALUES("TOYFAIR-2012", 702   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRADINGCARD-1", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRADINGCARD-2", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRADINGCARD-3", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRADINGCARD-4", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRADINGCARD-5", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRADINGCARD-6", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("TREE-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRICERATOPS-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("Troy-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRU01-1", 246   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUBATMOBILE-1", 708   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUBATSIGNAL-1", 697   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUBB8-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUCAPAM-1", 696   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUCHIMA-1", 571   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUCOGSWORTH-1", 608   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUFALCON-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUFRANKENSTEIN-1", 230   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUFRIENDS-1", 494   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUGHOST-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUHEARTBOX-1", 494   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUIRONMAN-1", 705   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUJEEP-1", 602   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUJEK14-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUJOKERMECH-1", 697   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUJWGATE-1", 602   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUKAYAK-1", 59   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRULUMIERE-1", 608   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNEXO-1", 605   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNEXO-2", 605   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNEXOMONSTER-1", 605   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNINJAGO-1", 435   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNINJAGO-2", 435   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNINJAGO-3", 435   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUNINJAGO-4", 435   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUPCAR-1", 61   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUPODIUM-1", 601   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRURUMBLE-1", 605   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUSANTA-1", 227   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUSHIELD-1", 697   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUSHIELD-2", 701   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUSHIELD-3", 696   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUSPIDERMAN-1", 706   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUSWMF-2", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUTRICERATOPS-1", 602   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUTRICERATOPS-2", 602   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUWEASLEYCAR-1", 246   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUWOOKIE-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUXWING-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TRUXWING2-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("TSUPER-1", 1   );
# INSERT INTO BUILD_HAS_THEME VALUES("TYRANNOSAURUS-1", 602   );
# INSERT INTO BUILD_HAS_THEME VALUES("UKDUPLOPATENT-1", 683   );
# INSERT INTO BUILD_HAS_THEME VALUES("UMBRELLA-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("UMBRELLA-2", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("UMBRELLA-3", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("UMBRELLA-4", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("UNITY-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("VALENTINE-1", 232   );
# INSERT INTO BUILD_HAS_THEME VALUES("VALENTINEPACK-1", 232   );
# INSERT INTO BUILD_HAS_THEME VALUES("VAMPIREBAT-1", 410   );
# INSERT INTO BUILD_HAS_THEME VALUES("Vancouver-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("Victor-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("VIDIYO-TILES-1", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("VIENNA-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("VIENNA-2", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("VIPPACKAGE-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("VISION-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-1", 133   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-10", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-11", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-12", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-13", 88   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-14", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-15", 298   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-17", 67   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-2", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-3", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-4", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-5", 144   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-7", 94   );
# INSERT INTO BUILD_HAS_THEME VALUES("VP-8", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("VPORIENT-1", 300   );
# INSERT INTO BUILD_HAS_THEME VALUES("vwkit-1", 365   );
# INSERT INTO BUILD_HAS_THEME VALUES("W098-1", 732   );
# INSERT INTO BUILD_HAS_THEME VALUES("WALLET-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("WALLET-3", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("WAND-1", 737   );
# INSERT INTO BUILD_HAS_THEME VALUES("WASHINGTONMONUMENT-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("WATCH-1", 732   );
# INSERT INTO BUILD_HAS_THEME VALUES("WATCH-2", 732   );
# INSERT INTO BUILD_HAS_THEME VALUES("WATCH-3", 732   );
# INSERT INTO BUILD_HAS_THEME VALUES("WATFORD-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("WAUWATOSA-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("WEETABIX1-1", 414   );
# INSERT INTO BUILD_HAS_THEME VALUES("WEETABIX2-1", 413   );
# INSERT INTO BUILD_HAS_THEME VALUES("WEETABIX3-1", 413   );
# INSERT INTO BUILD_HAS_THEME VALUES("WEETABIX4-1", 413   );
# INSERT INTO BUILD_HAS_THEME VALUES("WEETABIX5-1", 413   );
# INSERT INTO BUILD_HAS_THEME VALUES("WHITEHOUSE-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("WIESBADEN-1", 408   );
# INSERT INTO BUILD_HAS_THEME VALUES("WIIGAME-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("WIIGAME-3", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("WILLIAM-1", 535   );
# INSERT INTO BUILD_HAS_THEME VALUES("WISHINGWELL-1", 494   );
# INSERT INTO BUILD_HAS_THEME VALUES("WIZARD-CARDS-1", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("WIZARD-PORTRAITS-1", 746   );
# INSERT INTO BUILD_HAS_THEME VALUES("WLB6701-1", 761   );
# INSERT INTO BUILD_HAS_THEME VALUES("WOODENELEPHANT-1", 683   );
# INSERT INTO BUILD_HAS_THEME VALUES("WWGP-1", 475   );
# INSERT INTO BUILD_HAS_THEME VALUES("XBOXGAME-1", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("XBOXGAME-2", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("XBOXGAME-3", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("XBOXGAME-9", 742   );
# INSERT INTO BUILD_HAS_THEME VALUES("XMASTREE-1", 410   );
# INSERT INTO BUILD_HAS_THEME VALUES("XWING-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("XWING-2", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("YODACHRON-1", 158   );
# INSERT INTO BUILD_HAS_THEME VALUES("YOTO-1", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("YOTO-2", 501   );
# INSERT INTO BUILD_HAS_THEME VALUES("YTERRIER-1", 598   );
# INSERT INTO BUILD_HAS_THEME VALUES("ZX8000-1", 501   );
